# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
from scipy.stats import gaussian_kde
import numpy as np
import mpl_scatter_density
import seaborn as sns

# %%
df = pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# The dataset contains data about blocks of houses in California <br>
#
# - longitude : A measure of how far west a house is; a higher value is farther west
# - latitude : A measure of how far north a house is; a higher value is farther north
# - housing_median_age: Median age of a house within a block; a lower number is a newer building
# - total_rooms : total number of rooms within a block
# - total_bedrooms : total number of bedrooms within a block
# - population : Total number of people residing within a block
# - households: Total number of households, a group of people residing within a home unit, for a block
# - median_income: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
# - median_house_value: Median house value for households within a block (measured in US Dollars)
# - ocean_proximity: Location of the house w.r.t ocean/sea

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# For the purpose of exploring data I will replace the None values with the mean value of the column
df['total_bedrooms'].fillna(value=df['total_bedrooms'].mean(), inplace=True)

# %%
street_map = gpd.read_file('./data/cnty24k09_1_line.shp')
street_map = street_map.to_crs('epsg:4326')

# %% [markdown]
# Distribution of the data on the map of California

# %%
fig,ax = plt.subplots(figsize=(10,10))
street_map.plot(ax=ax, alpha = 0.4, color='grey')
df.plot(ax=ax, kind='scatter', x='longitude', y='latitude')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
values = np.vstack([df['longitude'], df['latitude']])
kernel = gaussian_kde(values)(values)

fig,ax = plt.subplots(figsize=(10,10))
street_map.plot(ax=ax, alpha = 0.4, color='grey')
sns.scatterplot(df['longitude'],df['latitude'], c=kernel)
# Out:
# /Users/noakawa/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
fig,ax = plt.subplots(figsize=(10,10))
street_map.plot(ax=ax, alpha = 0.4, color='grey')
sns.kdeplot(df['longitude'],df['latitude'], shade=True, shade_lowest=False)
# Out:
# /Users/noakawa/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/noakawa/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
street_map.plot(ax=ax, alpha = 0.4, color='grey')
density = ax.scatter_density(df['longitude'],df['latitude'])
fig.colorbar(density, label='Number of points per pixel')
# Out:
# /Users/noakawa/opt/anaconda3/lib/python3.9/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /Users/noakawa/opt/anaconda3/lib/python3.9/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
fig,ax = plt.subplots(figsize=(10,10))
street_map.plot(ax=ax, alpha = 0.4, color='grey')
df.plot(ax=ax, kind='scatter', x='longitude', y='latitude', alpha=0.4,
                  s=df['population']/50, label='population', figsize=(10,7),
                  c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# The graph here shows the population for each datapoint (bigger the point is, bigger population)<br>
# The colors are for the median house value

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    787.000000    280.000000       2.563400
# 50%        438.000000   1166.000000    409.000000       3.534800
# 75%        643.250000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
num_col = df.describe().columns

# %%
df.corrwith(df["median_house_value"]).sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049454
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# dtype: float64

# %%
pd.plotting.scatter_matrix(df, alpha=0.2,figsize=(20,20))
plt.show()

# %% [markdown]
# There is one weird pattern with the label. Looking at the last row which is the median_house value relation with all other features, that we have a lot of data points that have the same median value, which is the maximum one.<br>
# Besides that, the only feature where we can see some positive correlation is the median income, the correlation value is also 0.688075, which is the highest

# %%
df['median_house_value'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
df[df['median_house_value']==df['median_house_value'].max()].shape[0]
# Out:
# 965

# %% [markdown]
# This confirms we have a lot of samples with the same value

# %% [markdown]
# The curse of dimensionality means that when you increase the dimension (more variables) you need to exponentially increase the number of samples.

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# I will create a new feature that can explain how "crowded" are the houses. That is the population/households

# %%
df['crowded'] = df['population']/df['households']

# %%
df.corrwith(df["median_house_value"]).sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049454
# crowded              -0.023737
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# dtype: float64

# %% [markdown]
# not giving so much insights

# %%
df['tbedroom_per_thouse'] = df['total_bedrooms']/df['households']
df['troom_per_thouse'] = df['total_rooms']/df['households']
df['tbedrooms_per_trooms'] = df['total_bedrooms']/df['total_rooms']

# %%
df['houses_for_pop'] = df['households']/df['population']

# %% [markdown]
# Longitude and latitude on the graph have the same shape with the correlation so I can add them ??

# %%
df['ll'] = df['longitude']+df['latitude']

# %%
df.corrwith(df["median_house_value"]).sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# houses_for_pop        0.264910
# room_per_house        0.151948
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049454
# crowded              -0.023737
# population           -0.024650
# bedroom_per_house    -0.044265
# longitude            -0.045967
# latitude             -0.144160
# bed_per_rooms        -0.220049
# ll                   -0.491520
# dtype: float64

# %%
df.drop(columns=['households','total_bedrooms','crowded','population','longitude','latitude','tbedroom_per_thouse'], inplace=True)

# %%
df.corrwith(df["median_house_value"]).sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# houses_for_pop        0.264910
# room_per_house        0.151948
# total_rooms           0.134153
# housing_median_age    0.105623
# bed_per_rooms        -0.220049
# ll                   -0.491520
# dtype: float64

# %%
(df['median_income']/df['housing_median_age']).corr(df['median_house_value'])
# Out:
# 0.2078994791502222

# %%
# if you are younger you earn less
df['income_by_age'] = df['median_income']/df['housing_median_age']
df.drop(columns=['housing_median_age'], inplace=True)
